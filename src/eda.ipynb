# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.preprocessing import LabelEncoder

# %%
# Load the dataset
data = pd.read_csv('data\Customertravel.csv')

# Overview of the dataset
data.head()
# Out:
#    Age FrequentFlyer AnnualIncomeClass  ServicesOpted  \
# 0   34            No     Middle Income              6
# 1   34           Yes        Low Income              5
# 2   37            No     Middle Income              3
# 3   30            No     Middle Income              2
# 4   30            No        Low Income              1
#
#   AccountSyncedToSocialMedia BookedHotelOrNot  Target
# 0                         No              Yes       0
# 1                        Yes               No       1
# 2                        Yes               No       0
# 3                         No               No       0
# 4                         No               No       0

# %%
# Summary statistics
data.describe()
# Out:
#               Age  ServicesOpted      Target
# count  954.000000     954.000000  954.000000
# mean    32.109015       2.437107    0.234801
# std      3.337388       1.606233    0.424097
# min     27.000000       1.000000    0.000000
# 25%     30.000000       1.000000    0.000000
# 50%     31.000000       2.000000    0.000000
# 75%     35.000000       4.000000    0.000000
# max     38.000000       6.000000    1.000000

# %%
# Check null and data type
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 954 entries, 0 to 953
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         954 non-null    int64
#  1   FrequentFlyer               954 non-null    object
#  2   AnnualIncomeClass           954 non-null    object
#  3   ServicesOpted               954 non-null    int64
#  4   AccountSyncedToSocialMedia  954 non-null    object
#  5   BookedHotelOrNot            954 non-null    object
#  6   Target                      954 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 52.3+ KB

# %%
# Distribution of Age
plt.figure(figsize=(8, 6))
sns.histplot(data['Age'], bins=20, kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()
# Out:
# c:\Users\Ahmad Jibril H\Documents\Data pribadi\Coding\Projects\customer-churn-prediction\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ahmad Jibril H\Documents\Data pribadi\Coding\Projects\customer-churn-prediction\venv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Count of FrequentFlyer
plt.figure(figsize=(6, 4))
sns.countplot(data=data, x='FrequentFlyer')
plt.title('Count of FrequentFlyer')
plt.xlabel('FrequentFlyer')
plt.ylabel('Count')
plt.show()
# Out:
# c:\Users\Ahmad Jibril H\Documents\Data pribadi\Coding\Projects\customer-churn-prediction\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ahmad Jibril H\Documents\Data pribadi\Coding\Projects\customer-churn-prediction\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ahmad Jibril H\Documents\Data pribadi\Coding\Projects\customer-churn-prediction\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Count of AnnualIncomeClass
plt.figure(figsize=(8, 6))
sns.countplot(data=data, x='AnnualIncomeClass')
plt.title('Count of AnnualIncomeClass')
plt.xlabel('AnnualIncomeClass')
plt.ylabel('Count')
plt.show()
# Out:
# c:\Users\Ahmad Jibril H\Documents\Data pribadi\Coding\Projects\customer-churn-prediction\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ahmad Jibril H\Documents\Data pribadi\Coding\Projects\customer-churn-prediction\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ahmad Jibril H\Documents\Data pribadi\Coding\Projects\customer-churn-prediction\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Count of ServicesOpted
plt.figure(figsize=(8, 6))
sns.countplot(data=data, x='ServicesOpted')
plt.title('Count of ServicesOpted')
plt.xlabel('ServicesOpted')
plt.ylabel('Count')
plt.show()
# Out:
# c:\Users\Ahmad Jibril H\Documents\Data pribadi\Coding\Projects\customer-churn-prediction\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ahmad Jibril H\Documents\Data pribadi\Coding\Projects\customer-churn-prediction\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ahmad Jibril H\Documents\Data pribadi\Coding\Projects\customer-churn-prediction\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Count of AccountSyncedToSocialMedia
plt.figure(figsize=(6, 4))
sns.countplot(data=data, x='AccountSyncedToSocialMedia')
plt.title('Count of AccountSyncedToSocialMedia')
plt.xlabel('AccountSyncedToSocialMedia')
plt.ylabel('Count')
plt.show()
# Out:
# c:\Users\Ahmad Jibril H\Documents\Data pribadi\Coding\Projects\customer-churn-prediction\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ahmad Jibril H\Documents\Data pribadi\Coding\Projects\customer-churn-prediction\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ahmad Jibril H\Documents\Data pribadi\Coding\Projects\customer-churn-prediction\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Count of BookedHotelOrNot
plt.figure(figsize=(6, 4))
sns.countplot(data=data, x='BookedHotelOrNot')
plt.title('Count of BookedHotelOrNot')
plt.xlabel('BookedHotelOrNot')
plt.ylabel('Count')
plt.show()
# Out:
# c:\Users\Ahmad Jibril H\Documents\Data pribadi\Coding\Projects\customer-churn-prediction\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ahmad Jibril H\Documents\Data pribadi\Coding\Projects\customer-churn-prediction\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ahmad Jibril H\Documents\Data pribadi\Coding\Projects\customer-churn-prediction\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Count of Target
plt.figure(figsize=(6, 4))
sns.countplot(data=data, x='Target')
plt.title('Count of Churn (Target)')
plt.xlabel('Churn (Target)')
plt.ylabel('Count')
plt.show()
# Out:
# c:\Users\Ahmad Jibril H\Documents\Data pribadi\Coding\Projects\customer-churn-prediction\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ahmad Jibril H\Documents\Data pribadi\Coding\Projects\customer-churn-prediction\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ahmad Jibril H\Documents\Data pribadi\Coding\Projects\customer-churn-prediction\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Perform one-hot encoding for categorical variables
data_encoded = pd.get_dummies(data, columns=['FrequentFlyer', 'AnnualIncomeClass', 'AccountSyncedToSocialMedia', 'BookedHotelOrNot'])

data_encoded
# Out:
#      Age  ServicesOpted  Target  FrequentFlyer_No  FrequentFlyer_No Record  \
# 0     34              6       0              True                    False
# 1     34              5       1             False                    False
# 2     37              3       0              True                    False
# 3     30              2       0              True                    False
# 4     30              1       0              True                    False
# ..   ...            ...     ...               ...                      ...
# 949   31              1       0             False                    False
# 950   30              5       0              True                    False
# 951   37              4       0              True                    False
# 952   30              1       0              True                    False
# 953   31              1       0             False                    False
#
#      FrequentFlyer_Yes  AnnualIncomeClass_High Income  \
# ...

# %%
# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Convert 'FrequentFlyer' column to numerical values
data['FrequentFlyer'] = label_encoder.fit_transform(data['FrequentFlyer'])

# Convert 'AnnualIncomeClass' column to numerical values
data['AnnualIncomeClass'] = label_encoder.fit_transform(data['AnnualIncomeClass'])

# Convert 'No' to 0 and 'Yes' to 1 in 'AccountSyncedToSocialMedia' and 'BookedHotelOrNot' columns
data['AccountSyncedToSocialMedia'] = (data['AccountSyncedToSocialMedia'] == 'Yes').astype(int)
data['BookedHotelOrNot'] = (data['BookedHotelOrNot'] == 'Yes').astype(int)

print(data)
# Out:
#      Age  FrequentFlyer  AnnualIncomeClass  ServicesOpted  \
# 0     34              0                  2              6
# 1     34              2                  1              5
# 2     37              0                  2              3
# 3     30              0                  2              2
# 4     30              0                  1              1
# ..   ...            ...                ...            ...
# 949   31              2                  1              1
# 950   30              0                  2              5
# 951   37              0                  2              4
# 952   30              0                  1              1
# 953   31              2                  0              1
#
#      AccountSyncedToSocialMedia  BookedHotelOrNot  Target
# 0                             0                 1       0
# 1                             1                 0       1
# 2                             1                 0       0
# ...

# %%
# Correlation matrix
correlation_matrix = data.corr()

# Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
# Save the updated DataFrame to a CSV file
data.to_csv('data\\updated_customer_data.csv', index=False)
